# %% [markdown]
# ### Data Cleansing using Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Loading Raw Data

# %%
df = pd.read_csv('icc-test-batting-records-raw.csv')

df
# Out:
#                 Player  Country       Span  Matches  Innings  NotOut   Runs  \
# 0        SR Tendulkar       IND  1989-2013      200      329      33  15921
# 1          RT Ponting       AUS  1995-2012      168      287      29  13378
# 2           JH Kallis    ICC/SA  1995-2013      166      280      40  13289
# 3            R Dravid   ICC/IND  1996-2012      164      286      32  13288
# 4             AN Cook       ENG  2006-2018      161      291      16  12472
# 5       KC Sangakkara        SL  2000-2015      134      233      17  12400
# 6             BC Lara    ICC/WI  1990-2006      131      232       6  11953
# 7       S Chanderpaul        WI  1994-2015      164      280      49  11867
# 8       S Chanderpaul        WI  1994-2015      164      280      49  11867
# 9    DPMD Jayawardene        SL  1997-2014      149      252      15  11814
# 10          AR Border       AUS  1978-1994      156      265      44  11174
# ...

# %% [markdown]
# ### List Duplicated Records

# %%
df[df.duplicated(keep=False)]
# Out:
#             Player Country       Span  Matches  Innings  NotOut   Runs  \
# 7   S Chanderpaul       WI  1994-2015      164      280      49  11867
# 8   S Chanderpaul       WI  1994-2015      164      280      49  11867
# 15        HM Amla       SA  2004-2019      124      215      16   9282
# 16        HM Amla       SA  2004-2019      124      215      16   9282
#
#     HighestScore  Average  BallsFaced     SR  Hundred  Fiftys  Ducks  Fours  \
# 7            203    51.37       27395  43.31       30      66     15   1285
# 8            203    51.37       27395  43.31       30      66     15   1285
# 15           311    46.64       18573  49.97       28      41     13   1170
# 16           311    46.64       18573  49.97       28      41     13   1170
#
#     Sixers
# 7       36
# 8       36
# 15      14
# 16      14

# %% [markdown]
# ### Remove Duplicate Rows

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                 Player  Country       Span  Matches  Innings  NotOut   Runs  \
# 0        SR Tendulkar       IND  1989-2013      200      329      33  15921
# 1          RT Ponting       AUS  1995-2012      168      287      29  13378
# 2           JH Kallis    ICC/SA  1995-2013      166      280      40  13289
# 3            R Dravid   ICC/IND  1996-2012      164      286      32  13288
# 4             AN Cook       ENG  2006-2018      161      291      16  12472
# 5       KC Sangakkara        SL  2000-2015      134      233      17  12400
# 6             BC Lara    ICC/WI  1990-2006      131      232       6  11953
# 7       S Chanderpaul        WI  1994-2015      164      280      49  11867
# 9    DPMD Jayawardene        SL  1997-2014      149      252      15  11814
# 10          AR Border       AUS  1978-1994      156      265      44  11174
# 11            JE Root       ENG  2012-2023      130      238      19  11004
# ...

# %% [markdown]
# ### Replace null values with 'NA'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 101
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Player        100 non-null    object
#  1   Country       100 non-null    object
#  2   Span          97 non-null     object
#  3   Matches       100 non-null    int64
#  4   Innings       100 non-null    int64
#  5   NotOut        100 non-null    int64
#  6   Runs          100 non-null    int64
#  7   HighestScore  100 non-null    int64
#  8   Average       100 non-null    float64
#  9   BallsFaced    100 non-null    int64
#  10  SR            100 non-null    float64
#  11  Hundred       100 non-null    int64
#  12  Fiftys        100 non-null    int64
#  13  Ducks         100 non-null    int64
#  14  Fours         100 non-null    int64
#  15  Sixers        100 non-null    int64
# dtypes: float64(2), int64(11), object(3)
# memory usage: 13.3+ KB

# %%
df['Span'].fillna('NA',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 101
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Player        100 non-null    object
#  1   Country       100 non-null    object
#  2   Span          100 non-null    object
#  3   Matches       100 non-null    int64
#  4   Innings       100 non-null    int64
#  5   NotOut        100 non-null    int64
#  6   Runs          100 non-null    int64
#  7   HighestScore  100 non-null    int64
#  8   Average       100 non-null    float64
#  9   BallsFaced    100 non-null    int64
#  10  SR            100 non-null    float64
#  11  Hundred       100 non-null    int64
#  12  Fiftys        100 non-null    int64
#  13  Ducks         100 non-null    int64
#  14  Fours         100 non-null    int64
#  15  Sixers        100 non-null    int64
# dtypes: float64(2), int64(11), object(3)
# memory usage: 13.3+ KB

# %%
df
# Out:
#                 Player  Country       Span  Matches  Innings  NotOut   Runs  \
# 0        SR Tendulkar       IND  1989-2013      200      329      33  15921
# 1          RT Ponting       AUS  1995-2012      168      287      29  13378
# 2           JH Kallis    ICC/SA  1995-2013      166      280      40  13289
# 3            R Dravid   ICC/IND  1996-2012      164      286      32  13288
# 4             AN Cook       ENG  2006-2018      161      291      16  12472
# 5       KC Sangakkara        SL  2000-2015      134      233      17  12400
# 6             BC Lara    ICC/WI  1990-2006      131      232       6  11953
# 7       S Chanderpaul        WI  1994-2015      164      280      49  11867
# 9    DPMD Jayawardene        SL  1997-2014      149      252      15  11814
# 10          AR Border       AUS  1978-1994      156      265      44  11174
# 11            JE Root       ENG  2012-2023      130      238      19  11004
# ...
