# %%
import pandas as pd

# %% [markdown]
# Loading CSV files using Pandas

# %%
df = pd.read_csv('icc-test-batting-records.csv')
df
# Out:
#             Player  Country       Span  Matches  Innings  NotOut   Runs  \
# 0    SR Tendulkar       IND  1989-2013      200      329      33  15921
# 1      RT Ponting       AUS  1995-2012      168      287      29  13378
# 2       JH Kallis    ICC/SA  1995-2013      166      280      40  13289
# 3        R Dravid   ICC/IND  1996-2012      164      286      32  13288
# 4         AN Cook       ENG  2006-2018      161      291      16  12472
# ..             ...      ...        ...      ...      ...     ...    ...
# 95       WM Lawry       AUS  1961-1971       67      123      12   5234
# 96   LD Chandimal        SL  2011-2023       74      133      15   5231
# 97  Misbah-ul-Haq       PAK  2001-2017       75      132      20   5222
# 98      IT Botham       ENG  1977-1992      102      161       6   5200
# 99     TWM Latham        NZ  2014-2023       74      130       6   5150
#
#     HighestScore  Average  BallsFaced     SR  Hundred  Fiftys  Ducks  Fours  \
# ...

# %%
df.head(10)
# Out:
#               Player  Country       Span  Matches  Innings  NotOut   Runs  \
# 0      SR Tendulkar       IND  1989-2013      200      329      33  15921
# 1        RT Ponting       AUS  1995-2012      168      287      29  13378
# 2         JH Kallis    ICC/SA  1995-2013      166      280      40  13289
# 3          R Dravid   ICC/IND  1996-2012      164      286      32  13288
# 4           AN Cook       ENG  2006-2018      161      291      16  12472
# 5     KC Sangakkara        SL  2000-2015      134      233      17  12400
# 6           BC Lara    ICC/WI  1990-2006      131      232       6  11953
# 7     S Chanderpaul        WI  1994-2015      164      280      49  11867
# 8  DPMD Jayawardene        SL  1997-2014      149      252      15  11814
# 9         AR Border       AUS  1978-1994      156      265      44  11174
#
#    HighestScore  Average  BallsFaced     SR  Hundred  Fiftys  Ducks  Fours  \
# 0           248    53.78       29437  54.04       51      68     14   2058
# ...

# %%
df.tail(10)
# Out:
#             Player Country       Span  Matches  Innings  NotOut  Runs  \
# 90  KC Brathwaite       WI  2011-2023       85      163      10  5349
# 91    IM Chappell      AUS  1964-1980       75      136      10  5345
# 92      JG Wright       NZ  1978-1993       82      148       7  5334
# 93      MJ Slater      AUS  1993-2001       74      131       7  5312
# 94    N Kapil Dev      IND  1978-1994      131      184      15  5248
# 95       WM Lawry      AUS  1961-1971       67      123      12  5234
# 96   LD Chandimal       SL  2011-2023       74      133      15  5231
# 97  Misbah-ul-Haq      PAK  2001-2017       75      132      20  5222
# 98      IT Botham      ENG  1977-1992      102      161       6  5200
# 99     TWM Latham       NZ  2014-2023       74      130       6  5150
#
#     HighestScore  Average  BallsFaced     SR  Hundred  Fiftys  Ducks  Fours  \
# 90           212    34.96       13134  40.72       12      28     16    533
# ...

# %%
dfnew = df[['Player','Country','Matches','Runs']]
dfnew
# Out:
#             Player  Country  Matches   Runs
# 0    SR Tendulkar       IND      200  15921
# 1      RT Ponting       AUS      168  13378
# 2       JH Kallis    ICC/SA      166  13289
# 3        R Dravid   ICC/IND      164  13288
# 4         AN Cook       ENG      161  12472
# ..             ...      ...      ...    ...
# 95       WM Lawry       AUS       67   5234
# 96   LD Chandimal        SL       74   5231
# 97  Misbah-ul-Haq       PAK       75   5222
# 98      IT Botham       ENG      102   5200
# 99     TWM Latham        NZ       74   5150
#
# [100 rows x 4 columns]

# %%
df.count()
# Out:
# Player          100
# Country         100
# Span            100
# Matches         100
# Innings         100
# NotOut          100
# Runs            100
# HighestScore    100
# Average         100
# BallsFaced      100
# SR              100
# Hundred         100
# Fiftys          100
# Ducks           100
# Fours           100
# Sixers          100
# dtype: int64

# %%
df.describe()
# Out:
#           Matches     Innings      NotOut          Runs  HighestScore  \
# count  100.000000  100.000000  100.000000    100.000000    100.000000
# mean   105.790000  180.910000   16.100000   7618.630000    248.840000
# std     26.461062   43.857689    8.700981   2223.267532     56.926627
# min     52.000000   80.000000    6.000000   5150.000000    125.000000
# 25%     86.750000  150.250000   10.000000   5797.250000    205.000000
# 50%    103.000000  179.500000   15.000000   7213.000000    240.500000
# 75%    117.250000  200.500000   20.000000   8551.500000    283.250000
# max    200.000000  329.000000   49.000000  15921.000000    400.000000
#
#           Average    BallsFaced          SR     Hundred      Fiftys  \
# count  100.000000    100.000000  100.000000  100.000000  100.000000
# mean    46.396300  13716.190000   50.821500   20.660000   35.560000
# std      8.185666   5907.903528    9.105754    8.145421   11.437419
# ...

# %%
newdf = df[df['Average'] > 50]
newdf
# Out:
#               Player  Country       Span  Matches  Innings  NotOut   Runs  \
# 0      SR Tendulkar       IND  1989-2013      200      329      33  15921
# 1        RT Ponting       AUS  1995-2012      168      287      29  13378
# 2         JH Kallis    ICC/SA  1995-2013      166      280      40  13289
# 3          R Dravid   ICC/IND  1996-2012      164      286      32  13288
# 5     KC Sangakkara        SL  2000-2015      134      233      17  12400
# 6           BC Lara    ICC/WI  1990-2006      131      232       6  11953
# 7     S Chanderpaul        WI  1994-2015      164      280      49  11867
# 9         AR Border       AUS  1978-1994      156      265      44  11174
# 10          JE Root       ENG  2012-2023      130      238      19  11004
# 11         SR Waugh       AUS  1985-2004      168      260      46  10927
# 12      SM Gavaskar       IND  1971-1987      125      214      16  10122
# 13      Younis Khan       PAK  2000-2017      118      213      19  10099
# ...

# %%
newdf = df[df['Runs'] > 10000]
newdf
# Out:
#                Player  Country       Span  Matches  Innings  NotOut   Runs  \
# 0       SR Tendulkar       IND  1989-2013      200      329      33  15921
# 1         RT Ponting       AUS  1995-2012      168      287      29  13378
# 2          JH Kallis    ICC/SA  1995-2013      166      280      40  13289
# 3           R Dravid   ICC/IND  1996-2012      164      286      32  13288
# 4            AN Cook       ENG  2006-2018      161      291      16  12472
# 5      KC Sangakkara        SL  2000-2015      134      233      17  12400
# 6            BC Lara    ICC/WI  1990-2006      131      232       6  11953
# 7      S Chanderpaul        WI  1994-2015      164      280      49  11867
# 8   DPMD Jayawardene        SL  1997-2014      149      252      15  11814
# 9          AR Border       AUS  1978-1994      156      265      44  11174
# 10           JE Root       ENG  2012-2023      130      238      19  11004
# ...

# %%
df.drop('Span',axis='columns',inplace=True)

# %%
df
# Out:
#             Player  Country  Matches  Innings  NotOut   Runs  HighestScore  \
# 0    SR Tendulkar       IND      200      329      33  15921           248
# 1      RT Ponting       AUS      168      287      29  13378           257
# 2       JH Kallis    ICC/SA      166      280      40  13289           224
# 3        R Dravid   ICC/IND      164      286      32  13288           270
# 4         AN Cook       ENG      161      291      16  12472           294
# ..             ...      ...      ...      ...     ...    ...           ...
# 95       WM Lawry       AUS       67      123      12   5234           210
# 96   LD Chandimal        SL       74      133      15   5231           206
# 97  Misbah-ul-Haq       PAK       75      132      20   5222           161
# 98      IT Botham       ENG      102      161       6   5200           208
# 99     TWM Latham        NZ       74      130       6   5150           264
#
# ...

# %%
df.drop(99,axis='index',inplace=True)
df
# Out:
#             Player  Country  Matches  Innings  NotOut   Runs  HighestScore  \
# 0    SR Tendulkar       IND      200      329      33  15921           248
# 1      RT Ponting       AUS      168      287      29  13378           257
# 2       JH Kallis    ICC/SA      166      280      40  13289           224
# 3        R Dravid   ICC/IND      164      286      32  13288           270
# 4         AN Cook       ENG      161      291      16  12472           294
# ..             ...      ...      ...      ...     ...    ...           ...
# 94    N Kapil Dev       IND      131      184      15   5248           163
# 95       WM Lawry       AUS       67      123      12   5234           210
# 96   LD Chandimal        SL       74      133      15   5231           206
# 97  Misbah-ul-Haq       PAK       75      132      20   5222           161
# 98      IT Botham       ENG      102      161       6   5200           208
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
newdf.plot(kind = 'bar', x= 'Player', y = 'Hundred')
plt.show()
